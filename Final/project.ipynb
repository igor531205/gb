# %% [markdown]
# <a href="https://colab.research.google.com/github/igor531205/gb/blob/project/Final/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Библиотеки Python для Data Science: Numpy, Matplotlib, Scikit-learn.

# %% [markdown]
# ### Подключение библиотек и скриптов

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold, GridSearchCV

# %%
import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Пути к директориям и файлам

# %%
TRAIN_DATASET_PATH = 'train.csv'
TEST_DATASET_PATH = 'test.csv'

# %% [markdown]
# ### Подготовка датасета
#
# #### Описание датасета
#
# * **Id** - идентификационный номер квартиры
# * **DistrictId** - идентификационный номер района
# * **Rooms** - количество комнат
# * **Square** - площадь
# * **LifeSquare** - жилая площадь
# * **KitchenSquare** - площадь кухни
# * **Floor** - этаж
# * **HouseFloor** - количество этажей в доме
# * **HouseYear** - год постройки дома
# * **Ecology_1, Ecology_2, Ecology_3** - экологические показатели местности
# * **Social_1, Social_2, Social_3** - социальные показатели местности
# * **Healthcare_1, Helthcare_2** - показатели местности, связанные с охраной здоровья
# * **Shops_1, Shops_2** - показатели, связанные с наличием магазинов, торговых центров
# * **Price** - цена квартиры

# %%
df_train = pd.read_csv(TRAIN_DATASET_PATH, index_col='Id').sort_values(by=['Id'])
df_train.head()
# Out:
#     DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 0            0   1.00  109.14       84.61          15.00      6       15.00
# 2            2   1.00   34.47       16.07           5.00      5       18.00
# 5            5   3.00   57.61       38.96           5.00      3        9.00
# 6            6   1.00   42.47       40.01           1.00     14       17.00
# 10           6   3.00   75.89       78.32           1.00     11       17.00
#
#     HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 0        2011       0.32         B         B        25      4756        16
# 2        1969       0.00         B         B        33      7425         1
# 5        1974       0.15         B         B        16      3433         4
# 6        2014       0.24         B         B         5      1564         0
# 10       2014       0.24         B         B         5      1564         0
#
#     Healthcare_1  Helthcare_2  Shops_1 Shops_2      Price
# Id
# 0       2,857.00            5        8       B 289,034.39
# 2            NaN            2        5       B 174,548.97
# 5       2,643.00            4        5       B 258,091.88
# 6         540.00            0        0       B 127,196.76
# 10        540.00            0        0       B 218,500.75

# %%
df_train.shape
# Out:
# (10000, 19)

# %%
df_test = pd.read_csv(TEST_DATASET_PATH, index_col='Id').sort_values(by=['Id'])
df_test.head()
# Out:
#     DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 1            1   2.00   83.06       83.83           0.00     10       22.00
# 3            3   1.00   30.19       14.81           6.00      4        9.00
# 4            4   1.00   37.29       17.17           8.00      9        9.00
# 8            8   3.00   83.93       50.05           8.00      4       12.00
# 9            6   1.00   38.80       42.56           1.00      3       17.00
#
#     HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 1        1977       0.01         B         B         1       264         0
# 3        1970       0.27         B         B        37      5288         0
# 4        1970       0.33         B         B        12      2270        23
# 8        2007       0.09         B         B        21      4346         2
# 9        2017       0.24         B         B         5      1564         0
#
#     Healthcare_1  Helthcare_2  Shops_1 Shops_2
# Id
# 1            NaN            0        1       B
# 3       1,937.00            3        2       B
# 4       2,500.00            1        0       B
# 8         165.00            1        2       B
# 9         540.00            0        0       B

# %%
df_test.shape
# Out:
# (5000, 18)

# %% [markdown]
# ### Получаем информацию о данных

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 16798
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  int64
#  1   Rooms          10000 non-null  float64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     7887 non-null   float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  float64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Ecology_2      10000 non-null  object
#  10  Ecology_3      10000 non-null  object
#  11  Social_1       10000 non-null  int64
#  12  Social_2       10000 non-null  int64
#  13  Social_3       10000 non-null  int64
#  14  Healthcare_1   5202 non-null   float64
#  15  Helthcare_2    10000 non-null  int64
#  16  Shops_1        10000 non-null  int64
#  17  Shops_2        10000 non-null  object
#  18  Price          10000 non-null  float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.5+ MB

# %%
df_train.describe()
# Out:
#        DistrictId     Rooms    Square  LifeSquare  KitchenSquare     Floor  \
# count   10,000.00 10,000.00 10,000.00    7,887.00      10,000.00 10,000.00
# mean        50.40      1.89     56.32       37.20           6.27      8.53
# std         43.59      0.84     21.06       86.24          28.56      5.24
# min          0.00      0.00      1.14        0.37           0.00      1.00
# 25%         20.00      1.00     41.77       22.77           1.00      4.00
# 50%         36.00      2.00     52.51       32.78           6.00      7.00
# 75%         75.00      2.00     65.90       45.13           9.00     12.00
# max        209.00     19.00    641.07    7,480.59       2,014.00     42.00
#
#        HouseFloor     HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# count   10,000.00     10,000.00  10,000.00 10,000.00 10,000.00 10,000.00
# mean        12.61      3,990.17       0.12     24.69  5,352.16      8.04
# std          6.78    200,500.26       0.12     17.53  4,006.80     23.83
# min          0.00      1,910.00       0.00      0.00    168.00      0.00
# 25%          9.00      1,974.00       0.02      6.00  1,564.00      0.00
# 50%         13.00      1,977.00       0.08     25.00  5,285.00      2.00
# 75%         17.00      2,001.00       0.20     36.00  7,227.00      5.00
# max        117.00 20,052,011.00       0.52     74.00 19,083.00    141.00
#
#        Healthcare_1  Helthcare_2   Shops_1      Price
# count      5,202.00    10,000.00 10,000.00  10,000.00
# mean       1,142.90         1.32      4.23 214,138.86
# std        1,021.52         1.49      4.81  92,872.29
# min            0.00         0.00      0.00  59,174.78
# 25%          350.00         0.00      1.00 153,872.63
# 50%          900.00         1.00      3.00 192,269.64
# 75%        1,548.00         2.00      6.00 249,135.46
# max        4,849.00         6.00     23.00 633,233.47

# %%
df_train['DistrictId'].value_counts()
# Out:
# DistrictId
# 27     851
# 1      652
# 23     565
# 6      511
# 9      294
#       ...
# 196      1
# 207      1
# 209      1
# 174      1
# 205      1
# Name: count, Length: 205, dtype: int64

# %%
df_train['DistrictId'] = df_train['DistrictId'].astype(str)
df_test['DistrictId'] = df_test['DistrictId'].astype(str)

# %% [markdown]
# ### Обзор данных

# %%
plt.figure(figsize = (10, 5))

df_train['Price'].hist(bins=100)

plt.ylabel('Count')
plt.xlabel('Price')
plt.title('Price distribution')
# Out:
# Text(0.5, 1.0, 'Price distribution')

# %%
feature_num_names = df_train.drop('Price', axis=1).select_dtypes(include=['float64', 'int64']).columns.tolist()

# %%
df_train[feature_num_names].hist(figsize=(12,12), bins=50, grid=True)
# Out:
# array([[<Axes: title={'center': 'Rooms'}>,
#         <Axes: title={'center': 'Square'}>,
#         <Axes: title={'center': 'LifeSquare'}>,
#         <Axes: title={'center': 'KitchenSquare'}>],
#        [<Axes: title={'center': 'Floor'}>,
#         <Axes: title={'center': 'HouseFloor'}>,
#         <Axes: title={'center': 'HouseYear'}>,
#         <Axes: title={'center': 'Ecology_1'}>],
#        [<Axes: title={'center': 'Social_1'}>,
#         <Axes: title={'center': 'Social_2'}>,
#         <Axes: title={'center': 'Social_3'}>,
#         <Axes: title={'center': 'Healthcare_1'}>],
#        [<Axes: title={'center': 'Helthcare_2'}>,
#         <Axes: title={'center': 'Shops_1'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Обработка выбросов, ошибок, пропусков

# %%
df_train.isna().sum()
# Out:
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %% [markdown]
# #### Rooms

# %%
df_train['Rooms'].value_counts()
# Out:
# Rooms
# 2.00     3880
# 1.00     3705
# 3.00     2235
# 4.00      150
# 5.00       18
# 0.00        8
# 10.00       2
# 19.00       1
# 6.00        1
# Name: count, dtype: int64

# %%
sns.catplot(x='Rooms', y='Price', kind="box", data=df_train, aspect=2/1);

# %%
df_test['Rooms'].value_counts()
# Out:
# Rooms
# 2.00     2030
# 1.00     1769
# 3.00     1099
# 4.00       90
# 5.00        7
# 0.00        2
# 6.00        2
# 17.00       1
# Name: count, dtype: int64

# %%
plt.scatter(df_train['Rooms'], df_train['Square']);

# %%
df_train.loc[(df_train['Rooms'] > 6), 'Rooms'] = df_train['Rooms'].mode()[0]
df_test.loc[(df_test['Rooms'] > 6), 'Rooms'] = df_train['Rooms'].mode()[0]

# %%
plt.scatter(df_train['Rooms'], df_train['Square']);

# %%
plt.scatter(df_test['Rooms'], df_test['Square']);

# %% [markdown]
# #### Square

# %% [markdown]
# 1. исправить lifesquare в зависимости от кол-ва комнат и года постройки.
# 2. исправить kitchensquare в завис-ти от square, rooms, year

# %%
sns.jointplot(x=df_train['Square'], y=df_train['Price'], kind='scatter', height=5);

# %%
df_train.loc[df_train['Square'] > 300, 'Square'] =\
df_train.groupby(['Rooms', 'HouseYear'])['Square'].transform(lambda x: x.median())

df_test.loc[df_test['Square'] > 300, 'Square'] =\
df_test.groupby(['Rooms', 'HouseYear'])['Square'].transform(lambda x: x.median())

# %%
sns.jointplot(x=df_train['Square'], y=df_train['Price'], kind='scatter', height=5);

# %% [markdown]
# #### Lifesquare, KitchenSquare

# %%
df_train.loc[(df_train['LifeSquare'] > df_train['Square']) | (df_train['LifeSquare'].isna()), :]
# Out:
#       DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 10             6   3.00   75.89       78.32           1.00     11       17.00
# 28             9   2.00   63.64         NaN           1.00     17       18.00
# 29            22   3.00   73.93         NaN           1.00      4       17.00
# 32            25   3.00   88.41         NaN           1.00     21       25.00
# 41            30   2.00   59.02       59.44          12.00      5        5.00
# ...          ...    ...     ...         ...            ...    ...         ...
# 16757         23   1.00   41.46         NaN           1.00     11       17.00
# 16766         58   1.00   49.29         NaN           1.00      5        3.00
# 16772        109   3.00   32.80       36.66           6.00      2        9.00
# 16777         52   2.00   54.50         NaN           1.00     15       17.00
# 16781         27   1.00   36.14       36.71          36.00     19       19.00
#
#        HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 10          2014       0.24         B         B         5      1564         0
# 28          1977       0.16         B         B        25      5648         1
# 29          1977       0.12         B         B        30      6207         1
# 32          2019       0.07         B         B        53     13670         4
# 41          2016       0.00         B         B        22      6398       141
# ...          ...        ...       ...       ...       ...       ...       ...
# 16757       1977       0.08         B         B         6      1437         3
# 16766       1977       0.44         B         B        23      5735         3
# 16772       1979       0.14         B         B        30      6141        10
# 16777       1977       0.37         B         B        34      7065         1
# 16781       2017       0.07         B         B         2       629         1
#
#        Healthcare_1  Helthcare_2  Shops_1 Shops_2      Price
# Id
# 10           540.00            0        0       B 218,500.75
# 28            30.00            2        4       B 187,717.24
# 29         1,183.00            1        0       B 202,717.17
# 32              NaN            1       11       B 323,536.77
# 41         1,046.00            3       23       B 126,281.14
# ...             ...          ...      ...     ...        ...
# 16757           NaN            0        2       B 116,391.10
# 16766      1,084.00            0        5       B 122,670.47
# 16772        262.00            3        6       B 173,602.71
# 16777        750.00            2        5       B 150,775.31
# 16781           NaN            0        0       A 131,742.54
#
# [2596 rows x 19 columns]

# %%
df_test.loc[(df_test['LifeSquare'] > df_test['Square']) | (df_test['LifeSquare'].isna()), :]
# Out:
#       DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 1              1   2.00   83.06       83.83           0.00     10       22.00
# 9              6   1.00   38.80       42.56           1.00      3       17.00
# 30            23   2.00   64.42         NaN           1.00      8       17.00
# 54            34   2.00   59.94         NaN           1.00      5        1.00
# 79            27   2.00   67.86       67.87          13.00      4       12.00
# ...          ...    ...     ...         ...            ...    ...         ...
# 16754         33   2.00   45.64         NaN           0.00      4       16.00
# 16756         27   1.00   44.34         NaN           1.00      3        1.00
# 16764          1   1.00   41.69         NaN           1.00      7       22.00
# 16783         67   3.00   84.33         NaN           1.00     11       22.00
# 16786         23   1.00   44.67         NaN           1.00      7       25.00
#
#        HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 1           1977       0.01         B         B         1       264         0
# 9           2017       0.24         B         B         5      1564         0
# 30          1977       0.08         B         B         6      1437         3
# 54          1977       0.07         B         B        53     13670         4
# 79          2017       0.07         B         B         2       629         1
# ...          ...        ...       ...       ...       ...       ...       ...
# 16754       1977       0.24         B         B        16      3893        27
# 16756       1977       0.07         B         B         2       629         1
# 16764       1977       0.01         B         B         1       264         0
# 16783       1977       0.01         B         B        38      4788         2
# 16786       1977       0.08         B         B         6      1437         3
#
#        Healthcare_1  Helthcare_2  Shops_1 Shops_2
# Id
# 1               NaN            0        1       B
# 9            540.00            0        0       B
# 30              NaN            0        2       B
# 54              NaN            1       11       B
# 79              NaN            0        0       A
# ...             ...          ...      ...     ...
# 16754           NaN            3       10       B
# 16756           NaN            0        0       A
# 16764           NaN            0        1       B
# 16783           NaN            0        4       B
# 16786           NaN            0        2       B
#
# [1282 rows x 18 columns]

# %%
df_train['LfSqr/Sqr'] = np.where((df_train['LifeSquare'] < df_train['Square']) & \
                          (df_train['LifeSquare'].notna()), df_train['LifeSquare'] / \
                           df_train['Square'], None)

df_test['LfSqr/Sqr'] = np.where((df_test['LifeSquare'] < df_test['Square']) & \
                          (df_test['LifeSquare'].notna()), df_test['LifeSquare'] / \
                           df_test['Square'], None)

# %%
df_train.head()
# Out:
#    DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 0           0   1.00  109.14       84.61          15.00      6       15.00
# 2           2   1.00   34.47       16.07           5.00      5       18.00
# 5           5   3.00   57.61       38.96           5.00      3        9.00
# 6           6   1.00   42.47       40.01           1.00     14       17.00
# 10          6   3.00   75.89       78.32           1.00     11       17.00
#
#     HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 0        2011       0.32         B         B        25      4756        16
# 2        1969       0.00         B         B        33      7425         1
# 5        1974       0.15         B         B        16      3433         4
# 6        2014       0.24         B         B         5      1564         0
# 10       2014       0.24         B         B         5      1564         0
#
#     Healthcare_1  Helthcare_2  Shops_1 Shops_2      Price LfSqr/Sqr
# Id
# 0       2,857.00            5        8       B 289,034.39      0.78
# 2            NaN            2        5       B 174,548.97      0.47
# 5       2,643.00            4        5       B 258,091.88      0.68
# 6         540.00            0        0       B 127,196.76      0.94
# 10        540.00            0        0       B 218,500.75      None

# %%
df_train.loc[(df_train['LifeSquare'] > df_train['Square']) | (df_train['LifeSquare'].isna()), 'LifeSquare'] =\
df_train.groupby(['Rooms', 'HouseYear'])['Square'].transform(lambda x: x * df_train['LfSqr/Sqr'].median())

# %%
df_test.loc[(df_test['LifeSquare'] > df_test['Square']) | (df_test['LifeSquare'].isna()), 'LifeSquare'] =\
df_test.groupby(['Rooms', 'HouseYear'])['Square'].transform(lambda x: x * df_test['LfSqr/Sqr'].median())

# %%
df_train.head()
# Out:
#    DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 0           0   1.00  109.14       84.61          15.00      6       15.00
# 2           2   1.00   34.47       16.07           5.00      5       18.00
# 5           5   3.00   57.61       38.96           5.00      3        9.00
# 6           6   1.00   42.47       40.01           1.00     14       17.00
# 10          6   3.00   75.89       46.34           1.00     11       17.00
#
#     HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 0        2011       0.32         B         B        25      4756        16
# 2        1969       0.00         B         B        33      7425         1
# 5        1974       0.15         B         B        16      3433         4
# 6        2014       0.24         B         B         5      1564         0
# 10       2014       0.24         B         B         5      1564         0
#
#     Healthcare_1  Helthcare_2  Shops_1 Shops_2      Price LfSqr/Sqr
# Id
# 0       2,857.00            5        8       B 289,034.39      0.78
# 2            NaN            2        5       B 174,548.97      0.47
# 5       2,643.00            4        5       B 258,091.88      0.68
# 6         540.00            0        0       B 127,196.76      0.94
# 10        540.00            0        0       B 218,500.75      None

# %%
sns.jointplot(x=df_train['Square'], y=df_train['KitchenSquare'], kind='scatter', height=5);

# %%
df_train.loc[(df_train['KitchenSquare'] > 250) | \
             (df_train['KitchenSquare'] > df_train['Square'] - df_train['LifeSquare']), :]
# Out:
#       DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 58            36   1.00   34.78       33.12           6.00      3        5.00
# 112            6   1.00   41.78       38.40          10.00     12       17.00
# 247           23   3.00   68.07       67.98          10.00      9       10.00
# 251           27   1.00   52.30       45.15           9.00      3       12.00
# 287           53   3.00   80.52       79.55           1.00     12       21.00
# ...          ...    ...     ...         ...            ...    ...         ...
# 16605         23   2.00   55.26       54.97           1.00      5       17.00
# 16635         48   2.00   82.89       81.13          10.00     24       25.00
# 16700         27   1.00   40.74       40.15           1.00      9       17.00
# 16759         27   1.00   38.18       38.12          10.00     11       20.00
# 16781         27   1.00   36.14       22.07          36.00     19       19.00
#
#        HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# Id
# 58          1961       0.09         B         B         8      1497         5
# 112         2015       0.24         B         B         5      1564         0
# 247         2014       0.03         B         B         0       168         0
# 251         2019       0.07         B         B         2       629         1
# 287         2016       0.05         B         B        34      7759         0
# ...          ...        ...       ...       ...       ...       ...       ...
# 16605       2015       0.03         B         B         0       168         0
# 16635       2014       0.04         B         B        46      9515         5
# 16700       2016       0.01         B         B         4       915         0
# 16759       2017       0.01         B         B         4       915         0
# 16781       2017       0.07         B         B         2       629         1
#
#        Healthcare_1  Helthcare_2  Shops_1 Shops_2      Price LfSqr/Sqr
# Id
# 58              NaN            1        0       B 146,948.28      0.95
# 112          540.00            0        0       B 141,510.64      0.92
# 247             NaN            0        0       B 128,332.77      1.00
# 251             NaN            0        0       A 140,129.28      0.86
# 287          229.00            1        3       B 357,335.86      0.99
# ...             ...          ...      ...     ...        ...       ...
# 16605           NaN            0        0       B 112,509.02      0.99
# 16635           NaN            1       10       B 428,238.09      0.98
# 16700           NaN            0        0       B 109,493.04      0.99
# 16759           NaN            0        0       B 113,430.19      1.00
# 16781           NaN            0        0       A 131,742.54      None
#
# [374 rows x 20 columns]

# %%
df_train.loc[(df_train['KitchenSquare'] > 150) | (df_train['KitchenSquare'] > df_train['Square'] - df_train['LifeSquare']), \
             'KitchenSquare'] = df_train['Square'] - df_train['LifeSquare']

df_test.loc[(df_test['KitchenSquare'] > 150) | (df_test['KitchenSquare'] > df_test['Square'] - df_test['LifeSquare']), \
             'KitchenSquare'] = df_test['Square'] - df_test['LifeSquare']

# %%
df_train[['Square', 'LifeSquare', 'KitchenSquare']].describe()
# Out:
#          Square  LifeSquare  KitchenSquare
# count 10,000.00   10,000.00      10,000.00
# mean      56.17       35.00           5.58
# std       19.15       15.29           4.11
# min        1.14        0.37           0.00
# 25%       41.77       23.84           1.00
# 50%       52.51       32.58           6.00
# 75%       65.89       43.53           8.00
# max      275.65      233.95          58.00

# %% [markdown]
# #### HouseFloor, Floor

# %%
sns.jointplot(x=df_train['Floor'], y=df_train['HouseFloor'], kind='scatter', height=5);

# %%
sns.jointplot(x=df_test['Floor'], y=df_test['HouseFloor'], kind='scatter', height=5);

# %%
df_train.loc[df_train['HouseFloor'] == 0, 'HouseFloor'] = df_train['HouseFloor'].mode()[0]
df_test.loc[df_test['HouseFloor'] == 0, 'HouseFloor'] = df_train['HouseFloor'].mode()[0]

# %%
floor_outliers_train = df_train.loc[df_train['Floor'] > df_train['HouseFloor']].index
floor_outliers_test = df_test.loc[df_test['Floor'] > df_test['HouseFloor']].index

floor_outliers_train
# Out:
# Index([   33,    35,    46,    61,    69,    77,    88,    98,   107,   127,
#        ...
#        16664, 16674, 16697, 16702, 16711, 16715, 16726, 16753, 16766, 16785],
#       dtype='int64', name='Id', length=1578)

# %%
df_train.loc[floor_outliers_train, 'Floor'] = \
    df_train.loc[floor_outliers_train, 'HouseFloor'].apply(lambda x: random.randint(1, x))
df_test.loc[floor_outliers_test, 'Floor'] = \
    df_test.loc[floor_outliers_test, 'HouseFloor'].apply(lambda x: random.randint(1, x))

# %% [markdown]
# #### HouseYear

# %%
df_train['HouseYear'].sort_values(ascending=False)
# Out:
# Id
# 10814    20052011
# 11607        4968
# 2731         2020
# 9303         2020
# 14664        2020
#            ...
# 7920         1916
# 6751         1914
# 2085         1912
# 14556        1912
# 13288        1910
# Name: HouseYear, Length: 10000, dtype: int64

# %%
df_train.loc[df_train['HouseYear'] > 2020, 'HouseYear'] = 2011

# %% [markdown]
# ### Обработка редких категорий

# %% [markdown]
# #### DistrictId

# %%
print(df_train['DistrictId'].nunique(), ' уникальных  значений в train')
print(df_test['DistrictId'].nunique(), ' уникальных  значений в test')
# Out:
# 205  уникальных  значений в train
# 201  уникальных  значений в test

# %%
district_size = df_train['DistrictId'].value_counts().reset_index()

district_size
# Out:
#     DistrictId  count
# 0           27    851
# 1            1    652
# 2           23    565
# 3            6    511
# 4            9    294
# ..         ...    ...
# 200        196      1
# 201        207      1
# 202        209      1
# 203        174      1
# 204        205      1
#
# [205 rows x 2 columns]

# %%
sns.set(style="whitegrid", font_scale=1.0)
f, ax = plt.subplots(figsize=(12, 3))
palette = sns.color_palette("Spectral", len(district_size))
sns.barplot(y='count', x='DistrictId',
            data=district_size,
            order=district_size.sort_values(by='count', ascending=False)['DistrictId'],
            palette=palette
           );
ax.tick_params(axis='x', rotation=90)
ax.xaxis.set_major_locator(plt.MaxNLocator(40))

# %%
district_size.loc[district_size['count'] > 50, :]
# Out:
#    DistrictId  count
# 0          27    851
# 1           1    652
# 2          23    565
# 3           6    511
# 4           9    294
# 5          62    247
# 6          30    228
# 7          58    179
# 8          53    174
# 9          21    165
# 10         52    143
# 11          8    142
# 12         11    129
# 13         46    119
# 14         61    118
# 15         45    116
# 16         74    114
# 17         34    111
# 18         57    107
# 19         44    104
# 20         47     97
# 21         13     97
# 22         99     97
# 23        101     97
# 24          7     92
# 25         48     90
# 26         29     89
# 27         94     89
# 28         41     87
# 29          3     82
# 30         84     80
# 31         28     79
# 32         22     78
# 33          2     78
# 34         25     77
# 35         85     76
# 36         93     73
# 37         37     72
# 38         90     72
# 39         96     71
# 40         59     67
# 41         75     66
# 42         26     65
# 43         88     64
# 44        128     64
# 45         12     64
# 46         66     62
# 47         67     61
# 48         17     59
# 49         55     58
# 50         39     57
# 51         10     56
# 52        105     55
# 53         31     55
# 54         18     51

# %%
district_size_test = df_test['DistrictId'].value_counts().reset_index()

district_size_test
# Out:
#     DistrictId  count
# 0           27    391
# 1            1    344
# 2           23    264
# 3            6    257
# 4            9    132
# ..         ...    ...
# 196        165      1
# 197        186      1
# 198        175      1
# 199        182      1
# 200        212      1
#
# [201 rows x 2 columns]

# %%
sns.set(style="whitegrid", font_scale=1.0)
f, ax = plt.subplots(figsize=(12, 3))
sns.barplot(y='count', x='DistrictId',
            data=district_size_test,
            order=district_size_test.sort_values(by='count', ascending=False)['DistrictId'],
            palette=palette
           );
ax.tick_params(axis='x', rotation=90)
ax.xaxis.set_major_locator(plt.MaxNLocator(50))

# %%
district_size_test.loc[district_size_test['count'] > 50, :]
# Out:
#    DistrictId  count
# 0          27    391
# 1           1    344
# 2          23    264
# 3           6    257
# 4           9    132
# 5          62    122
# 6          30    115
# 7          53     91
# 8          58     91
# 9          21     70
# 10         52     67
# 11          8     64
# 12         61     64
# 13         74     61
# 14         34     61
# 15         46     61
# 16         29     60
# 17          3     56
# 18         57     54
# 19         48     51

# %%
districts_popular = district_size.loc[district_size['count'] > 50, 'DistrictId'].tolist()

# %%
district_size.loc[~district_size['DistrictId'].isin(districts_popular), 'DistrictId'] = 999
district_size = district_size.groupby('DistrictId')['count'].agg(
                            DistrictSize='median')
district_size.reset_index(level='DistrictId', inplace=True)
district_size
# Out:
#    DistrictId  DistrictSize
# 0         999         11.00
# 1           1        652.00
# 2          10         56.00
# 3         101         97.00
# 4         105         55.00
# 5          11        129.00
# 6          12         64.00
# 7         128         64.00
# 8          13         97.00
# 9          17         59.00
# 10         18         51.00
# 11          2         78.00
# 12         21        165.00
# 13         22         78.00
# 14         23        565.00
# 15         25         77.00
# 16         26         65.00
# 17         27        851.00
# 18         28         79.00
# 19         29         89.00
# 20          3         82.00
# 21         30        228.00
# 22         31         55.00
# 23         34        111.00
# 24         37         72.00
# 25         39         57.00
# 26         41         87.00
# 27         44        104.00
# 28         45        116.00
# 29         46        119.00
# 30         47         97.00
# 31         48         90.00
# 32         52        143.00
# 33         53        174.00
# 34         55         58.00
# 35         57        107.00
# 36         58        179.00
# 37         59         67.00
# 38          6        511.00
# 39         61        118.00
# 40         62        247.00
# 41         66         62.00
# 42         67         61.00
# 43          7         92.00
# 44         74        114.00
# 45         75         66.00
# 46          8        142.00
# 47         84         80.00
# 48         85         76.00
# 49         88         64.00
# 50          9        294.00
# 51         90         72.00
# 52         93         73.00
# 53         94         89.00
# 54         96         71.00
# 55         99         97.00

# %%
df_train.loc[~df_train['DistrictId'].isin(districts_popular), 'DistrictId'] = 999
df_test.loc[~df_test['DistrictId'].isin(districts_popular), 'DistrictId'] = 999

# %%
df_test['DistrictId'].value_counts()
# Out:
# DistrictId
# 999    1235
# 27      391
# 1       344
# 23      264
# 6       257
# 9       132
# 62      122
# 30      115
# 53       91
# 58       91
# 21       70
# 52       67
# 8        64
# 61       64
# 46       61
# 74       61
# 34       61
# 29       60
# 3        56
# 57       54
# 48       51
# 45       49
# 47       49
# 13       47
# 101      46
# 44       46
# 11       45
# 41       44
# 67       43
# 2        43
# 94       43
# 96       42
# 25       42
# 99       42
# 85       41
# 31       41
# 55       41
# 93       40
# 37       40
# 7        38
# 28       38
# 12       36
# 88       36
# 75       34
# 26       33
# 22       33
# 90       30
# 39       29
# 17       29
# 84       28
# 128      27
# 66       27
# 18       26
# 59       23
# 105      22
# 10       16
# Name: count, dtype: int64

# %% [markdown]
# ### Обработка редких категорий

# %% [markdown]
# #### DistrictSize

# %%
df_train = df_train.merge(district_size, on='DistrictId', how='left').set_index(df_train.index)
df_test = df_test.merge(district_size, on='DistrictId', how='left').set_index(df_test.index)
df_train.head(10)
# Out:
#    DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 0         999   1.00  109.14       84.61          15.00      6       15.00
# 2           2   1.00   34.47       16.07           5.00      5       18.00
# 5         999   3.00   57.61       38.96           5.00      3        9.00
# 6           6   1.00   42.47       40.01           1.00     14       17.00
# 10          6   3.00   75.89       46.34           1.00     11       17.00
# 11          9   3.00   76.37       45.67          10.00     14       14.00
# 14         12   2.00   57.64       34.43           8.00     17       17.00
# 15         13   1.00   46.83       21.76           9.00      6       25.00
# 17          9   2.00   60.15       30.07          11.00      6       14.00
# 19        999   3.00   64.08       44.55           6.00      5        9.00
#
#     HouseYear  Ecology_1 Ecology_2  ... Social_1  Social_2  Social_3  \
# Id                                  ...
# 0        2011       0.32         B  ...       25      4756        16
# 2        1969       0.00         B  ...       33      7425         1
# 5        1974       0.15         B  ...       16      3433         4
# 6        2014       0.24         B  ...        5      1564         0
# 10       2014       0.24         B  ...        5      1564         0
# 11       1996       0.07         B  ...       53     13670         4
# 14       1990       0.09         B  ...       74     19083         2
# 15       2001       0.09         B  ...       74     19083         2
# 17       1999       0.31         B  ...       11      2748         1
# 19       1980       0.04         B  ...       52     11217         1
#
#     Healthcare_1  Helthcare_2  Shops_1  Shops_2      Price  LfSqr/Sqr  \
# Id
# 0       2,857.00            5        8        B 289,034.39       0.78
# 2            NaN            2        5        B 174,548.97       0.47
# 5       2,643.00            4        5        B 258,091.88       0.68
# 6         540.00            0        0        B 127,196.76       0.94
# 10        540.00            0        0        B 218,500.75       None
# 11           NaN            1       11        B 307,799.67       0.60
# 14           NaN            5       15        B 236,258.55       0.60
# 15           NaN            5       15        B 213,389.22       0.46
# 17           NaN            0        0        B 206,431.59       0.50
# 19      2,300.00            1        7        B 258,719.29       0.70
#
#    DistrictSize
# Id
# 0         11.00
# 2         78.00
# 5         11.00
# 6        511.00
# 10       511.00
# 11       294.00
# 14        64.00
# 15        97.00
# 17       294.00
# 19        11.00
#
# [10 rows x 21 columns]

# %% [markdown]
# #### PricePerSquare

# %%
df_train['PricePerSquare'] = df_train['Price'] / df_train['Square']

# %% [markdown]
# #### PricePerSquareByDistrict

# %%
price_by_district = df_train.groupby(['DistrictId'], as_index=False)\
                        .agg({'PricePerSquare':'median'})\
                        .rename(columns={'PricePerSquare':'PricePerSquareByDistrict'})

price_by_district
# Out:
#    DistrictId  PricePerSquareByDistrict
# 0         999                  4,762.74
# 1           1                  3,251.65
# 2          10                  4,458.89
# 3         101                  4,188.41
# 4         105                  4,644.69
# 5          11                  4,134.35
# 6          12                  4,162.24
# 7         128                  4,333.67
# 8          13                  4,273.75
# 9          17                  5,029.78
# 10         18                  4,120.03
# 11          2                  4,550.71
# 12         21                  3,986.57
# 13         22                  3,553.68
# 14         23                  2,273.50
# 15         25                  4,166.86
# 16         26                  4,745.15
# 17         27                  2,761.27
# 18         28                  4,385.49
# 19         29                  4,186.66
# 20          3                  3,892.20
# 21         30                  2,830.36
# 22         31                  5,480.22
# 23         34                  4,304.30
# 24         37                  4,430.24
# 25         39                  4,249.13
# 26         41                  4,437.30
# 27         44                  4,610.40
# 28         45                  5,288.64
# 29         46                  4,608.81
# 30         47                  4,181.96
# 31         48                  5,115.76
# 32         52                  2,938.05
# 33         53                  4,845.92
# 34         55                  4,081.40
# 35         57                  4,127.81
# 36         58                  2,949.98
# 37         59                  4,736.63
# 38          6                  2,861.08
# 39         61                  4,528.02
# 40         62                  2,613.22
# 41         66                  5,003.89
# 42         67                  4,229.83
# 43          7                  4,562.03
# 44         74                  3,319.32
# 45         75                  4,262.32
# 46          8                  4,124.22
# 47         84                  4,229.55
# 48         85                  4,452.23
# 49         88                  4,424.29
# 50          9                  3,206.59
# 51         90                  4,451.24
# 52         93                  3,494.43
# 53         94                  4,219.99
# 54         96                  4,025.34
# 55         99                  3,992.03

# %%
df_train = df_train.merge(price_by_district, on=['DistrictId'], how='left').set_index(df_train.index)
df_test = df_test.merge(price_by_district, on=['DistrictId'], how='left').set_index(df_test.index)

# %%
df_train.head()
# Out:
#    DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Id
# 0         999   1.00  109.14       84.61          15.00      6       15.00
# 2           2   1.00   34.47       16.07           5.00      5       18.00
# 5         999   3.00   57.61       38.96           5.00      3        9.00
# 6           6   1.00   42.47       40.01           1.00     14       17.00
# 10          6   3.00   75.89       46.34           1.00     11       17.00
#
#     HouseYear  Ecology_1 Ecology_2  ... Social_3  Healthcare_1  Helthcare_2  \
# Id                                  ...
# 0        2011       0.32         B  ...       16      2,857.00            5
# 2        1969       0.00         B  ...        1           NaN            2
# 5        1974       0.15         B  ...        4      2,643.00            4
# 6        2014       0.24         B  ...        0        540.00            0
# 10       2014       0.24         B  ...        0        540.00            0
#
#     Shops_1  Shops_2      Price  LfSqr/Sqr DistrictSize  PricePerSquare  \
# Id
# 0         8        B 289,034.39       0.78        11.00        2,648.18
# 2         5        B 174,548.97       0.47        78.00        5,063.46
# 5         5        B 258,091.88       0.68        11.00        4,480.14
# 6         0        B 127,196.76       0.94       511.00        2,995.20
# 10        0        B 218,500.75       None       511.00        2,879.25
#
#    PricePerSquareByDistrict
# Id
# 0                  4,762.74
# 2                  4,550.71
# 5                  4,762.74
# 6                  2,861.08
# 10                 2,861.08
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Отбор признаков

# %%
df_train.to_csv('train_prepared.csv')
df_test.to_csv('test_prepared.csv')

# %%
feature_names = df_train.columns
feature_names.tolist()
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Ecology_2',
#  'Ecology_3',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Shops_2',
#  'Price',
#  'LfSqr/Sqr',
#  'DistrictSize',
#  'PricePerSquare',
#  'PricePerSquareByDistrict']

# %%
target_name = ['Price']
feature_names = [
#             'DistrictId',
             'Rooms',
             'Square',
#             'LifeSquare',
             'KitchenSquare',
             'Floor',
             'HouseFloor',
             'HouseYear',
             'Ecology_1',
#             'Ecology_2',
#             'Ecology_3',
             'Social_1',
             'Social_2',
             'Social_3',
#             'Healthcare_1',
#             'Helthcare_2',
             'Shops_1',
#             'Shops_2',
#             'Price',
             'DistrictSize',
#             'PricePerSquare',
             'PricePerSquareByDistrict',
#             'RoomSquare'
                ]

# %%
X = df_train[feature_names]
y = df_train[target_name]

X_test = df_test[feature_names]

# %%
len(feature_names)
# Out:
# 13

# %% [markdown]
# ### Построение модели Random Forest

# %% [markdown]
# #### Перекрестная проверка модели

# %%
forest = RandomForestRegressor(max_depth=19,
                               max_features=6,
                               n_estimators=100,
                               random_state=42)

# %%
kf = KFold(n_splits=20, random_state=42, shuffle=True)

cv_score = cross_val_score(forest, X, y, scoring='r2', cv=kf)
print('R2: {:.5f}'.format(cv_score.mean()))
# Out:
# R2: 0.74837

# %% [markdown]
# #### Важность признаков

# %%
forest.fit(X, y)
importances = forest.feature_importances_
feat_importances = pd.Series(importances, index=feature_names)
feat_importances.sort_values(ascending=True, inplace=True)

# %%
feat_importances.plot(kind='barh', figsize=(10, 6));

# %% [markdown]
# ### Настройка гиперпараметров модели

# %%
params = {
    'n_estimators': [300],
    'max_depth': [16], #[15,16,17]
    'max_features': [5] #[5,6,7]
}

# %%
forest_grid = GridSearchCV(forest, params, scoring='r2',
                  cv=KFold(n_splits=10, random_state=42, shuffle=True),
                  n_jobs=-1)
forest_grid.fit(X, y)
print(forest_grid.best_params_)
print('R2 на train: {:.5f}'.format(forest_grid.best_score_))
# Out:
# {'max_depth': 16, 'max_features': 5, 'n_estimators': 300}
# R2 на train: 0.75117

# %% [markdown]
# ### Прогнозирование на тестовом датасете

# %%
forest_best = forest_grid.best_estimator_

y_pred = forest_best.predict(X_test)

# %%
preds = pd.DataFrame()
preds['Id'] = X_test.index
preds['Price'] = y_pred
preds.head()
# Out:
#    Id      Price
# 0   1 254,246.40
# 1   3 145,707.17
# 2   4 213,710.75
# 3   8 321,831.28
# 4   9 128,168.15

# %%
preds.to_csv('predictions.csv', index=False)
